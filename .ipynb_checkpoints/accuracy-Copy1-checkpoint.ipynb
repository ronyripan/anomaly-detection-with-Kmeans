# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
old_dataset = pd.read_csv('heart.csv')

# %%
from sklearn.model_selection import train_test_split

# %%
old_features = old_dataset.drop('target',axis = 1)
old_target = old_dataset['target']

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(old_features, old_target, test_size=0.30, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
error_rate = []

# Will take some time
for i in range(1,40):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train1,y_train1)
    pred_i = knn.predict(X_test1)
    error_rate.append(np.mean(pred_i != y_test1))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

# %%
knneig = KNeighborsClassifier(n_neighbors=22)
knneig.fit(X_train1, y_train1)
pred_knneigh = knneig.predict(X_test1)
score_knneigh_before = accuracy_score(y_test1, pred_knneigh)
print("Score KNeighnors :",score_knneigh_before)
print(classification_report(y_test1, pred_knneigh))
print(confusion_matrix(y_test1, pred_knneigh))
# Out:
# Score KNeighnors : 0.6923076923076923
#               precision    recall  f1-score   support
#
#            0       0.64      0.71      0.67        41
#            1       0.74      0.68      0.71        50
#
#     accuracy                           0.69        91
#    macro avg       0.69      0.69      0.69        91
# weighted avg       0.70      0.69      0.69        91
#
# [[29 12]
#  [16 34]]

# %%
kmeans = pd.read_csv("k2.csv")

# %%
kmeans_features = kmeans.drop('target',axis = 1)
kmeans_target = kmeans['target']

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(kmeans_features, kmeans_target, test_size=0.30, random_state=42)

# %%
error_rate = []

# Will take some time
for i in range(1,40):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train2,y_train2)
    pred_i = knn.predict(X_test2)
    error_rate.append(np.mean(pred_i != y_test2))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
knneig = KNeighborsClassifier(n_neighbors=7)
knneig.fit(X_train2, y_train2)
pred_knneigh = knneig.predict(X_test2)
score_knneigh_before = accuracy_score(y_test2, pred_knneigh)
print("Score KNeighnors :",score_knneigh_before)
print(classification_report(y_test2, pred_knneigh))
# Out:
# Score KNeighnors : 0.6931818181818182
#               precision    recall  f1-score   support
#
#            0       0.59      0.65      0.62        34
#            1       0.76      0.72      0.74        54
#
#     accuracy                           0.69        88
#    macro avg       0.68      0.68      0.68        88
# weighted avg       0.70      0.69      0.70        88

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train1, y_train1)
rfc_pred = rfc.predict(X_test1)
print(classification_report(y_test1,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80        41
#            1       0.83      0.86      0.84        50
#
#     accuracy                           0.82        91
#    macro avg       0.82      0.82      0.82        91
# weighted avg       0.82      0.82      0.82        91

# %%
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train2, y_train2)
rfc_pred = rfc.predict(X_test2)
print(accuracy_score(y_test2,rfc_pred))
print(classification_report(y_test2,rfc_pred))
# Out:
# 0.8522727272727273
#               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.81        34
#            1       0.87      0.89      0.88        54
#
#     accuracy                           0.85        88
#    macro avg       0.85      0.84      0.84        88
# weighted avg       0.85      0.85      0.85        88

# %%
from sklearn.svm import SVC

# %%
param_grid = {'C': [0.1,1, 10, 100, 1000], 'gamma': [1,0.1,0.01,0.001,0.0001], 'kernel': ['rbf']} 
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=3)
# May take awhile!
grid.fit(X_train1,y_train1)
grid_predictions = grid.predict(X_test1)
print(accuracy_score(y_test1,grid_predictions))
print(classification_report(y_test1,grid_predictions))
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.535, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.535, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.548, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.548, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.548, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.535, total=   0.0s
# ...

# %%
param_grid = {'C': [0.1,1, 10, 100, 1000], 'gamma': [1,0.1,0.01,0.001,0.0001], 'kernel': ['rbf']} 
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=3)
# May take awhile!
grid.fit(X_train2,y_train2)
grid_predictions = grid.predict(X_test2)
print(accuracy_score(y_test2,grid_predictions))
print(classification_report(y_test2,grid_predictions))
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.512, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.512, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.512, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.525, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# ...

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gauss_clf = GaussianNB()
gauss_clf.fit(X_train1, y_train1)
pred_gauss = gauss_clf.predict(X_test1)
print(accuracy_score(y_test1, pred_gauss))
print(classification_report(y_test1,pred_gauss))
# Out:
# 0.8351648351648352
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83        41
#            1       0.89      0.80      0.84        50
#
#     accuracy                           0.84        91
#    macro avg       0.84      0.84      0.83        91
# weighted avg       0.84      0.84      0.84        91

# %%
gauss_clf = GaussianNB()
gauss_clf.fit(X_train2, y_train2)
pred_gauss = gauss_clf.predict(X_test2)
print(accuracy_score(y_test2, pred_gauss))
print(classification_report(y_test2,pred_gauss))
# Out:
# 0.8409090909090909
#               precision    recall  f1-score   support
#
#            0       0.86      0.71      0.77        34
#            1       0.83      0.93      0.88        54
#
#     accuracy                           0.84        88
#    macro avg       0.85      0.82      0.83        88
# weighted avg       0.84      0.84      0.84        88

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train1,y_train1)
predictions = logmodel.predict(X_test1)
print(accuracy_score(y_test1, predictions))
print(classification_report(y_test1,predictions))
# Out:
# 0.8131868131868132
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79        41
#            1       0.82      0.84      0.83        50
#
#     accuracy                           0.81        91
#    macro avg       0.81      0.81      0.81        91
# weighted avg       0.81      0.81      0.81        91
# C:\Users\muktadir\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train2,y_train2)
predictions = logmodel.predict(X_test2)
print(accuracy_score(y_test2, predictions))
print(classification_report(y_test2,predictions))
# Out:
# 0.8522727272727273
#               precision    recall  f1-score   support
#
#            0       0.86      0.74      0.79        34
#            1       0.85      0.93      0.88        54
#
#     accuracy                           0.85        88
#    macro avg       0.85      0.83      0.84        88
# weighted avg       0.85      0.85      0.85        88
# C:\Users\muktadir\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
